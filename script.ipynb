# %% [markdown]
# Requirements:
# Fetch Data:
# Write a Python script to perform an HTTP GET request to fetch JSON data from a public API (example URL: https://jsonplaceholder.typicode.com/todos).
#
# Process Data with Conditional List Comprehension:
# Extract titles from the JSON data, but only include those that contain a specific string (e.g., 'qui').
# Implement this using list comprehension.
#
# Display Results with f-Strings:
# Format and print the filtered titles using f-strings.
# Ensure that each printed title is a string.
#
# Type Checking:
# Demonstrate checking whether one of the extracted titles is of type int.
#
# Notes:
# Aim for clear, efficient, and concise code.
# Basic error handling is encouraged, but focus on the core functionalities.
# You can use online resources for reference, but ensure the coding is your own work.
# Please record your coding session using a screen recorder, explaining your thought process as you write the script.
# Provide the result in a publicly viewable google doc link, with the link to the session recording included inside.

# %%
import json
import requests

url = 'https://jsonplaceholder.typicode.com/todos'
txt = json.loads(requests.get(url).text)
print(txt)
# Out:
# [{'userId': 1, 'id': 1, 'title': 'delectus aut autem', 'completed': False}, {'userId': 1, 'id': 2, 'title': 'quis ut nam facilis et officia qui', 'completed': False}, {'userId': 1, 'id': 3, 'title': 'fugiat veniam minus', 'completed': False}, {'userId': 1, 'id': 4, 'title': 'et porro tempora', 'completed': True}, {'userId': 1, 'id': 5, 'title': 'laboriosam mollitia et enim quasi adipisci quia provident illum', 'completed': False}, {'userId': 1, 'id': 6, 'title': 'qui ullam ratione quibusdam voluptatem quia omnis', 'completed': False}, {'userId': 1, 'id': 7, 'title': 'illo expedita consequatur quia in', 'completed': False}, {'userId': 1, 'id': 8, 'title': 'quo adipisci enim quam ut ab', 'completed': True}, {'userId': 1, 'id': 9, 'title': 'molestiae perspiciatis ipsa', 'completed': False}, {'userId': 1, 'id': 10, 'title': 'illo est ratione doloremque quia maiores aut', 'completed': True}, {'userId': 1, 'id': 11, 'title': 'vero rerum temporibus dolor', 'completed': True}, {'userId': 1, 'id': 12, 'title': 'ipsa repellendus fugit nisi', 'completed': True}, {'userId': 1, 'id': 13, 'title': 'et doloremque nulla', 'completed': False}, {'userId': 1, 'id': 14, 'title': 'repellendus sunt dolores architecto voluptatum', 'completed': True}, {'userId': 1, 'id': 15, 'title': 'ab voluptatum amet voluptas', 'completed': True}, {'userId': 1, 'id': 16, 'title': 'accusamus eos facilis sint et aut voluptatem', 'completed': True}, {'userId': 1, 'id': 17, 'title': 'quo laboriosam deleniti aut qui', 'completed': True}, {'userId': 1, 'id': 18, 'title': 'dolorum est consequatur ea mollitia in culpa', 'completed': False}, {'userId': 1, 'id': 19, 'title': 'molestiae ipsa aut voluptatibus pariatur dolor nihil', 'completed': True}, {'userId': 1, 'id': 20, 'title': 'ullam nobis libero sapiente ad optio sint', 'completed': True}, {'userId': 2, 'id': 21, 'title': 'suscipit repellat esse quibusdam voluptatem incidunt', 'completed': False}, {'userId': 2, 'id': 22, 'title': 'distinctio vitae autem nihil ut molestias quo', 'completed': True}, {'userId': 2, 'id': 23, 'title': 'et itaque necessitatibus maxime molestiae qui quas velit', 'completed': False}, {'userId': 2, 'id': 24, 'title': 'adipisci non ad dicta qui amet quaerat doloribus ea', 'completed': False}, {'userId': 2, 'id': 25, 'title': 'voluptas quo tenetur perspiciatis explicabo natus', 'completed': True}, {'userId': 2, 'id': 26, 'title': 'aliquam aut quasi', 'completed': True}, {'userId': 2, 'id': 27, 'title': 'veritatis pariatur delectus', 'completed': True}, {'userId': 2, 'id': 28, 'title': 'nesciunt totam sit blanditiis sit', 'completed': False}, {'userId': 2, 'id': 29, 'title': 'laborum aut in quam', 'completed': False}, {'userId': 2, 'id': 30, 'title': 'nemo perspiciatis repellat ut dolor libero commodi blanditiis omnis', 'completed': True}, {'userId': 2, 'id': 31, 'title': 'repudiandae totam in est sint facere fuga', 'completed': False}, {'userId': 2, 'id': 32, 'title': 'earum doloribus ea doloremque quis', 'completed': False}, {'userId': 2, 'id': 33, 'title': 'sint sit aut vero', 'completed': False}, {'userId': 2, 'id': 34, 'title': 'porro aut necessitatibus eaque distinctio', 'completed': False}, {'userId': 2, 'id': 35, 'title': 'repellendus veritatis molestias dicta incidunt', 'completed': True}, {'userId': 2, 'id': 36, 'title': 'excepturi deleniti adipisci voluptatem et neque optio illum ad', 'completed': True}, {'userId': 2, 'id': 37, 'title': 'sunt cum tempora', 'completed': False}, {'userId': 2, 'id': 38, 'title': 'totam quia non', 'completed': False}, {'userId': 2, 'id': 39, 'title': 'doloremque quibusdam asperiores libero corrupti illum qui omnis', 'completed': False}, {'userId': 2, 'id': 40, 'title': 'totam atque quo nesciunt', 'completed': True}, {'userId': 3, 'id': 41, 'title': 'aliquid amet impedit consequatur aspernatur placeat eaque fugiat suscipit', 'completed': False}, {'userId': 3, 'id': 42, 'title': 'rerum perferendis error quia ut eveniet', 'completed': False}, {'userId': 3, 'i ...

# %%
print(f'Number of dictionaries inside list: {len(txt)}')
# Out:
# Number of dictionaries inside list: 200

# %%
all_keys = set()
for x in txt:
    all_keys |= set(list(x.keys()))
print(all_keys)
# Out:
# {'title', 'completed', 'id', 'userId'}

# %%
import pandas as pd
list_for_pandas = []
for x in txt:
    list_for_pandas += [[x[key] for key in ['userId','id','title','completed']]]
df = pd.DataFrame(list_for_pandas,columns=['userId','id','title','completed'])
df
# Out:
#      userId   id                                              title  completed
# 0         1    1                                 delectus aut autem      False
# 1         1    2                 quis ut nam facilis et officia qui      False
# 2         1    3                                fugiat veniam minus      False
# 3         1    4                                   et porro tempora       True
# 4         1    5  laboriosam mollitia et enim quasi adipisci qui...      False
# ..      ...  ...                                                ...        ...
# 195      10  196                consequuntur aut ut fugit similique       True
# 196      10  197                  dignissimos quo nobis earum saepe       True
# 197      10  198                       quis eius est sint explicabo       True
# 198      10  199                       numquam repellendus a magnam       True
# 199      10  200                       ipsam aperiam voluptates qui      False
#
# [200 rows x 4 columns]

# %%
df.describe()
# Out:
#            userId          id
# count  200.000000  200.000000
# mean     5.500000  100.500000
# std      2.879489   57.879185
# min      1.000000    1.000000
# 25%      3.000000   50.750000
# 50%      5.500000  100.500000
# 75%      8.000000  150.250000
# max     10.000000  200.000000

# %%
print(f'False rows: {len(df[df['completed'] == False])}')
# Out:
# False rows: 110

# %%
print(f'False rows: {len(df[df['completed'] == True])}')
# Out:
# False rows: 90

# %%
for userid in set(df['userId'].values):
    print(f'The User {userid} has {len(df[df['userId'] == userid])}' )
# Out:
# The User 1 has 20
# The User 2 has 20
# The User 3 has 20
# The User 4 has 20
# The User 5 has 20
# The User 6 has 20
# The User 7 has 20
# The User 8 has 20
# The User 9 has 20
# The User 10 has 20

# %%
df['Number_of_letters'] = df['title'].apply(lambda x: len(x))
df
# Out:
#      userId   id                                              title  \
# 0         1    1                                 delectus aut autem
# 1         1    2                 quis ut nam facilis et officia qui
# 2         1    3                                fugiat veniam minus
# 3         1    4                                   et porro tempora
# 4         1    5  laboriosam mollitia et enim quasi adipisci qui...
# ..      ...  ...                                                ...
# 195      10  196                consequuntur aut ut fugit similique
# 196      10  197                  dignissimos quo nobis earum saepe
# 197      10  198                       quis eius est sint explicabo
# 198      10  199                       numquam repellendus a magnam
# 199      10  200                       ipsam aperiam voluptates qui
#
#      completed  Number_of_letters
# 0        False                 18
# 1        False                 34
# 2        False                 19
# 3         True                 16
# 4        False                 63
# ..         ...                ...
# 195       True                 35
# 196       True                 33
# 197       True                 28
# 198       True                 28
# 199      False                 28
#
# [200 rows x 5 columns]

# %%
user_map_nbofletters = {}
for userid in set(df['userId'].values):
    numer_of_letters = sum(df[df['userId'] == userid]['Number_of_letters'].values)
    print(f'The User {userid} has {numer_of_letters}')
    user_map_nbofletters[userid] = numer_of_letters
print(user_map_nbofletters)
# Out:
# The User 1 has 689
# The User 2 has 774
# The User 3 has 963
# The User 4 has 938
# The User 5 has 763
# The User 6 has 851
# The User 7 has 790
# The User 8 has 926
# The User 9 has 844
# The User 10 has 749
# {1: 689, 2: 774, 3: 963, 4: 938, 5: 763, 6: 851, 7: 790, 8: 926, 9: 844, 10: 749}

# %%
user_map_nbofletters = { x:y for x,y in sorted(user_map_nbofletters.items(), key=lambda item: item[1])}

# %%
user_map_nbofletters
# Out:
# {1: 689,
#  10: 749,
#  5: 763,
#  2: 774,
#  7: 790,
#  9: 844,
#  6: 851,
#  8: 926,
#  4: 938,
#  3: 963}

# %%
import re
# delectus aut autem -> d.*ect.*aut.*m
df['re_combiantion'] = df['title'].apply(lambda x: True if re.search('^d.*?ect.*?aut.*?m$',x) else False)
df
# Out:
#      userId   id                                              title  \
# 0         1    1                                 delectus aut autem
# 1         1    2                 quis ut nam facilis et officia qui
# 2         1    3                                fugiat veniam minus
# 3         1    4                                   et porro tempora
# 4         1    5  laboriosam mollitia et enim quasi adipisci qui...
# ..      ...  ...                                                ...
# 195      10  196                consequuntur aut ut fugit similique
# 196      10  197                  dignissimos quo nobis earum saepe
# 197      10  198                       quis eius est sint explicabo
# 198      10  199                       numquam repellendus a magnam
# 199      10  200                       ipsam aperiam voluptates qui
#
#      completed  Number_of_letters  re_combiantion
# 0        False                 18            True
# 1        False                 34           False
# 2        False                 19           False
# 3         True                 16           False
# 4        False                 63           False
# ..         ...                ...             ...
# 195       True                 35           False
# 196       True                 33           False
# 197       True                 28           False
# 198       True                 28           False
# 199      False                 28           False
#
# [200 rows x 6 columns]

# %%
df[df['re_combiantion'] == True]
# Out:
#    userId  id               title  completed  Number_of_letters  \
# 0       1   1  delectus aut autem      False                 18
#
#    re_combiantion
# 0            True

# %%
# qui
df['re_combiantion'] = df['title'].apply(lambda x: True if 'qui' in x else False)
df[df['re_combiantion'] == True]
# Out:
#      userId   id                                              title  \
# 1         1    2                 quis ut nam facilis et officia qui
# 4         1    5  laboriosam mollitia et enim quasi adipisci qui...
# 5         1    6  qui ullam ratione quibusdam voluptatem quia omnis
# 6         1    7                  illo expedita consequatur quia in
# 9         1   10       illo est ratione doloremque quia maiores aut
# ..      ...  ...                                                ...
# 176       9  177  et placeat temporibus voluptas est tempora quo...
# 180      10  181           ut cupiditate sequi aliquam fuga maiores
# 192      10  193  rerum debitis voluptatem qui eveniet tempora d...
# 197      10  198                       quis eius est sint explicabo
# 199      10  200                       ipsam aperiam voluptates qui
#
#      completed  Number_of_letters  re_combiantion
# 1        False                 34            True
# 4        False                 63            True
# 5        False                 49            True
# 6        False                 33            True
# 9         True                 44            True
# ..         ...                ...             ...
# 176      False                 57            True
# 180      False                 40            True
# 192       True                 57            True
# 197       True                 28            True
# 199      False                 28            True
#
# [83 rows x 6 columns]

# %% [markdown]
# # Check errors and check types

# %%
for line in df.to_dict(orient='records'):
    try:
        print(f"Element between d and b: {re.search('.*?d(.*?)b.*?',line['title']).group(1)}")
        print(f"Original: {line['title']}\n")
    except:
        print('Fail, element dosent exist')
# Out:
# Fail, element dosent exist
# Fail, element dosent exist
# Fail, element dosent exist
# Fail, element dosent exist
# Fail, element dosent exist
# Fail, element dosent exist
# Fail, element dosent exist
# Element between d and b: ipisci enim quam ut a
# Original: quo adipisci enim quam ut ab
#
# Fail, element dosent exist
# Fail, element dosent exist
# Fail, element dosent exist
# Fail, element dosent exist
# Fail, element dosent exist
# Fail, element dosent exist
# Fail, element dosent exist
# Fail, element dosent exist
# Fail, element dosent exist
# Fail, element dosent exist
# Fail, element dosent exist
# Fail, element dosent exist
# Fail, element dosent exist
# Fail, element dosent exist
# Fail, element dosent exist
# Element between d and b: ipisci non ad dicta qui amet quaerat dolori
# Original: adipisci non ad dicta qui amet quaerat doloribus ea
#
# Fail, element dosent exist
# Fail, element dosent exist
# Fail, element dosent exist
# Fail, element dosent exist
# Fail, element dosent exist
# Element between d and b: olor li
# Original: nemo perspiciatis repellat ut dolor libero commodi blanditiis omnis
#
# Fail, element dosent exist
# Element between d and b: olori
# Original: earum doloribus ea doloremque quis
#
# Fail, element dosent exist
# Fail, element dosent exist
# Fail, element dosent exist
# Fail, element dosent exist
# Fail, element dosent exist
# Fail, element dosent exist
# Element between d and b: oloremque qui
# Original: doloremque quibusdam asperiores libero corrupti illum qui omnis
#
# Fail, element dosent exist
# Fail, element dosent exist
# Fail, element dosent exist
# Fail, element dosent exist
# Element between d and b: e
# Original: cum debitis quis accusamus doloremque ipsa natus sapiente omnis
#
# Fail, element dosent exist
# Fail, element dosent exist
# Fail, element dosent exist
# Fail, element dosent exist
# Element between d and b: e
# Original: ut necessitatibus aut maiores debitis officia blanditiis velit et
#
# Element between d and b: itate necessitati
# Original: cupiditate necessitatibus ullam aut quis dolor voluptate
#
# Element between d and b: istinctio exercitationem a
# Original: distinctio exercitationem ab doloribus
#
# Fail, element dosent exist
# Fail, element dosent exist
# Fail, element dosent exist
# Fail, element dosent exist
# Element between d and b: eleniti ea tempori
# Original: deleniti ea temporibus enim
#
# Element between d and b: olori
# Original: pariatur et magnam ea doloribus similique voluptatem rerum quia
#
# Element between d and b: icta totam qui explica
# Original: est dicta totam qui explicabo doloribus qui dignissimos
#
# Element between d and b:  la
# Original: perspiciatis velit id laborum placeat iusto et aliquam odio
#
# Fail, element dosent exist
# Fail, element dosent exist
# Fail, element dosent exist
# Fail, element dosent exist
# Fail, element dosent exist
# Fail, element dosent exist
# Fail, element dosent exist
# Fail, element dosent exist
# Fail, element dosent exist
# Element between d and b: olori
# Original: doloribus sint dolorum ab adipisci itaque dignissimos aliquam suscipit
#
# Fail, element dosent exist
# Fail, element dosent exist
# Fail, element dosent exist
# Fail, element dosent exist
# Element between d and b: ita tempore no
# Original: expedita tempore nobis eveniet laborum maiores
#
# Fail, element dosent exist
# Fail, element dosent exist
# Fail, element dosent exist
# Fail, element dosent exist
# Fail, element dosent exist
# Fail, element dosent exist
# Fail, element dosent exist
# Fail, element dosent exist
# Fail, element dosent exist
# Fail, element dosent exist
# Fail, element dosent exist
# Fail, element dosent exist
# Fail, element dosent exist
# Fail, element dosent exist
# Fail, element dosent exist
# Fail, element dosent exist
# Fail, element dosent exist
# Fail, element dosent exist
# Element between d and b: io iure consequatur molestiae qui
# Original: odio iure consequatur molestiae quibusdam necessitatibus quia sint
#
# Fail, element dosent exist
# Fail, element dosent exist
# Fail, element dosent exist
# Element between d and b: olorum la
# Original: dolorum laboriosam eos qui iure aliquam
#
# Element between d and b: e
# Original: debitis accusantium ut quo facilis nihil quis sapiente necessitatibus
#
# Fail, element dosent exist
# Fail, element dosent exist
# Fail, element dosent exist
# Element between d and b:  a
# Original: sed ab consequatur
#
# Fail, element dosent exist
# Fail, element dosent exist
# Fail, element dosent exist
# Element between d and b:  illo quis voluptatem tempori
# Original: ad illo quis voluptatem temporibus
#
# Fail, element dosent exist
# Fail, element dosent exist
# Fail, element dosent exist
# Fail, element dosent exist
# Fail, element dosent exist
# Fail, element dosent exist
# Fail, element dosent exist
# Element between d and b: itate quos possimus corporis quisquam exercitationem
# Original: cupiditate quos possimus corporis quisquam exercitationem beatae
#
# Fail, element dosent exist
# Fail, element dosent exist
# Fail, element dosent exist
# Fail, element dosent exist
# Fail, element dosent exist
# Element between d and b: olorem la
# Original: dolorem laboriosam vel voluptas et aliquam quasi
#
# Fail, element dosent exist
# Element between d and b: ent aut no
# Original: provident aut nobis culpa
#
# Fail, element dosent exist
# Fail, element dosent exist
# Fail, element dosent exist
# Fail, element dosent exist
# Fail, element dosent exist
# Fail, element dosent exist
# Fail, element dosent exist
# Element between d and b:  eveniet harum la
# Original: nulla aliquid eveniet harum laborum libero alias ut unde
#
# Fail, element dosent exist
# Fail, element dosent exist
# Fail, element dosent exist
# Element between d and b: olori
# Original: molestiae doloribus et laborum quod ea
#
# Fail, element dosent exist
# Fail, element dosent exist
# Fail, element dosent exist
# Fail, element dosent exist
# Element between d and b: olori
# Original: consequatur doloribus id possimus voluptas a voluptatem
#
# Element between d and b: itiis deserunt quia sed la
# Original: aut consectetur in blanditiis deserunt quia sed laboriosam
#
# Element between d and b: e
# Original: explicabo consectetur debitis voluptates quas quae culpa rerum non
#
# Fail, element dosent exist
# Fail, element dosent exist
# Fail, element dosent exist
# Fail, element dosent exist
# Element between d and b: io li
# Original: molestiae suscipit ratione nihil odio libero impedit vero totam
#
# Fail, element dosent exist
# Fail, element dosent exist
# Fail, element dosent exist
# Fail, element dosent exist
# Element between d and b: ipisci dicta qui quo ea explica
# Original: accusamus adipisci dicta qui quo ea explicabo sed vero
#
# Fail, element dosent exist
# Fail, element dosent exist
# Fail, element dosent exist
# Fail, element dosent exist
# Element between d and b: a qui
# Original: nam quia quia nulla repellat assumenda quibusdam sit nobis
#
# Fail, element dosent exist
# Element between d and b: e
# Original: debitis vitae delectus et harum accusamus aut deleniti a
#
# Element between d and b: e
# Original: debitis adipisci quibusdam aliquam sed dolore ea praesentium nobis
#
# Fail, element dosent exist
# Fail, element dosent exist
# Fail, element dosent exist
# Element between d and b: antium et voluptatem la
# Original: natus corrupti maxime laudantium et voluptatem laboriosam odit
#
# Fail, element dosent exist
# Fail, element dosent exist
# Fail, element dosent exist
# Fail, element dosent exist
# Element between d and b: ae quia qui sunt li
# Original: recusandae quia qui sunt libero
#
# Fail, element dosent exist
# Element between d and b: olori
# Original: quisquam aliquam quia doloribus aut
#
# Fail, element dosent exist
# Fail, element dosent exist
# Fail, element dosent exist
# Fail, element dosent exist
# Fail, element dosent exist
# Fail, element dosent exist
# Fail, element dosent exist
# Fail, element dosent exist
# Fail, element dosent exist
# Element between d and b: e
# Original: debitis nisi et dolorem repellat et
#
# Fail, element dosent exist
# Fail, element dosent exist
# Fail, element dosent exist
# Fail, element dosent exist
# Element between d and b: ignissimos sed dolori
# Original: voluptates dignissimos sed doloribus animi quaerat aut
#
# Fail, element dosent exist
# Fail, element dosent exist
# Fail, element dosent exist
# Fail, element dosent exist
# Fail, element dosent exist
# Fail, element dosent exist
# Fail, element dosent exist
# Element between d and b: e
# Original: rerum debitis voluptatem qui eveniet tempora distinctio a
#
# Fail, element dosent exist
# Fail, element dosent exist
# Fail, element dosent exist
# Element between d and b: ignissimos quo no
# Original: dignissimos quo nobis earum saepe
#
# Fail, element dosent exist
# Fail, element dosent exist
# Fail, element dosent exist

# %%
for value,col in zip(df.values[0],['userid','id','title','completed']):
    print(f'The column {col} type is {type(value)}')
# Out:
# The column userid type is <class 'int'>
# The column id type is <class 'int'>
# The column title type is <class 'str'>
# The column completed type is <class 'bool'>
